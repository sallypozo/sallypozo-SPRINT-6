# %%
#Ejercicio 1
#Crea al menos dos modelos de regresión diferentes para intentar predecir lo mejor
#posible el precio de las viviendas ( MEDV )del archivo adjunto.

#1 Importar las bibliotecas
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures # Polinomial
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score
#2 Importando el conjunto de datos
datos = pd.read_csv('housing.csv') 
datos.columns # nombres de las columnas
print(datos.head())
datos.columns=['CRIM', 'ZN', 'INDUS' , 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
datos.columns
print(datos.head())
datos.dtypes


#Primer modelo: Regresión lineal simple con scikit-learn
#-----------------------------
# definir los datos/predictores como los nombres de características preestablecidos   
import numpy as np
from sklearn.linear_model import LinearRegression
X = datos.loc[:, ['CRIM', 'ZN', 'INDUS' , 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = datos.iloc[:, -1].values
#Step 3: Create a model and fit it
model = LinearRegression()
model.fit(X, y)
LinearRegression()
#Step 4: Get results
r_sq = model.score(X, y)
print(f"coefficient of determination: {r_sq}")
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
#Paso 5: Predecir la respuesta
y_pred = model.predict(X) 
print(f"predicted response:\n{y_pred}")
# Out:
#    0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0  0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1  0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2  0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3  0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4  0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
#
#    396.90  4.98  24.00
# 0  396.90  9.14   21.6
# 1  392.83  4.03   34.7
# 2  394.63  2.94   33.4
# 3  396.90  5.33   36.2
# 4  394.12  5.21   28.7
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0     17.8
# 1  0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0     17.8
# 2  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0     18.7
# ...

# %%
#Modelo: Regresión polinomial con scikit-learn
#-----------------------------
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
X = datos.loc[:, ['B', 'LSTAT']].values
y = datos.iloc[:, -1].values
transformer = PolynomialFeatures(degree=2, include_bias=False)
transformer.fit(X)
PolynomialFeatures(include_bias=False)
X_ = transformer.transform(X)
X_ = PolynomialFeatures(degree=2, include_bias=False).fit_transform(X)
model2 = LinearRegression().fit(X_, y)
r_pl = model2.score(X_, y)
print(f"coefficient of determination: {r_pl}")
print(f"intercept: {model2.intercept_}")
print(f"coefficients: {model2.coef_}")
print(f"predicted response:\n{y_pred}")

#Segundo Modelo: Regresión del árbol de decisión
#-----------------------------

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#2 Importing the dataset
X = datos.loc[:, ['CRIM', 'ZN', 'INDUS' , 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y1 = datos.iloc[:, -1].values
from sklearn.tree import DecisionTreeRegressor
model1 = DecisionTreeRegressor() 
model1.fit(X1, y1)
p1 = model1.score(X1, y1)
print(f"coefficient of determination: {p1}")

#Segundo Modelo: Regresión del árbol de decisión (2FORMA)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

from sklearn.tree import DecisionTreeRegressor
model3 = DecisionTreeRegressor()
model3.fit(X_train, y_train)
p3 = model3.score(X_train, y_train)
print(f"coefficient of determination: {p3}")
# Out:
# coefficient of determination: 0.6493376295300287
# intercept: 39.4605023891773
# coefficients: [ 3.73182497e-02 -2.36843085e+00 -7.32666035e-05  7.99408211e-05
#   4.42400111e-02]
# predicted response:
# [25.05287327 30.5907312  28.63998016 27.97059175 25.29657018 23.03963072
#  19.56217091 11.52873396 18.94872811 19.01674878 21.62613881 20.92677299
#  19.57687345 19.30919665 19.32137284 20.5450635  16.92594186 16.19430306
#  18.43132193 12.53519092 17.6921236  15.83860708 13.8164631  15.69345558
#  13.40346367 15.48263814 14.71733886 19.56352038 20.8903587  11.4566605
#  18.08485645  8.79158064 14.29854028 13.71253782 23.84897342 22.37025818
#  23.13481158 22.93131107 31.36565713 34.22080763 28.01344736 25.20478584
#  24.60533017 22.94611541 22.1053107  20.41881839 18.03312507  9.08192067
#  17.20620474 21.2804276  23.98680713 27.65996583 24.05227761 15.38892115
#  31.12640681 24.89202721 33.12366596 21.75986617 21.07613882 17.86178493
# ...

# %%
#Ejercicio 2
#Compárales en base al MSE y al R2
#Comparación en función al MSE
#-----------------------------------



#Comparación en función al R2
#-----------------------------------
print(f"coefficient of determination: {r_sq}")
print(f"coefficient of determination: {r_pl}")
# Out:
# coefficient of determination: 0.9290125946857599
# coefficient of determination: 0.6493376295300287

# %%
#Ejercicio 3
#Entrenalos utilizando los diferentes parámetros que admiten para intentar mejorar su predicción.

MEDV = datos[['MEDV']].to_numpy()
Sales = datos[['Sales']].to_numpy()
TV_train, TV_test, Sales_train, Sales_test = train_test_split(TV, Sales, test_size=0.3, random_state=2022)
TV_train.shape

# %%
#Ejercicio 4
#Compara su rendimiento empleando la aproximación traicionando/test o empleando todos los datos (validación interna).

...
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (338, 14) (167, 14) (338,) (167,)

# %%
# Ejercicio 5
# No utilices la variable del número de habitaciones ( RM ) a la hora de realizar predicciones.

#Primer modelo: Regresión lineal simple con scikit-learn
#-----------------------------
# definir los datos/predictores como los nombres de características preestablecidos   
import numpy as np
from sklearn.linear_model import LinearRegression
X = datos.loc[:, ['CRIM', 'ZN', 'INDUS' , 'CHAS', 'NOX', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']].values
y = datos.iloc[:, -1].values
#Step 3: Create a model and fit it
model = LinearRegression()
model.fit(X, y)
LinearRegression()
#Step 4: Get results
r_sq = model.score(X, y)
print(f"coefficient of determination: {r_sq}")
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
#Paso 5: Predecir la respuesta
y_pred = model.predict(X) 
print(f"predicted response:\n{y_pred}")
# Out:
# coefficient of determination: 0.6980716149266408
# intercept: 69.51625453650217
# slope: [-1.15142648e-01  6.54592766e-02 -3.83183163e-02  2.91150308e+00
#  -2.08446070e+01  2.59328956e-02 -1.72157816e+00  3.95733786e-01
#  -1.45290573e-02 -1.14940212e+00  6.75224402e-03 -7.74281404e-01]
# predicted response:
# [25.38004502 28.84753812 27.48952069 25.86792862 26.06328277 24.29057561
#  19.18330951 10.63411017 19.32976595 17.40914982 22.92138812 21.18880108
#  20.68522773 20.0332392  20.73645198 21.38613895 16.92585219 18.19574267
#  20.06370474 13.10381332 18.22478157 14.5500252  13.67560323 15.79648373
#  14.69711993 16.25663911 14.19009987 18.37362552 19.11727669 10.93085161
#  18.67187303  6.18783294 15.00050596 12.75718456 25.9040971  24.22352761
#  24.92643233 23.69561457 32.47322418 34.12869152 26.20713962 25.53664489
#  24.34479885 23.5498055  23.99133352 20.92574782 17.63222709  8.30158961
#  18.3794143  21.966131   25.52186814 27.66715381 25.23638364 15.69883204
# ...
